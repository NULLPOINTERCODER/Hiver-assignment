# %% [markdown]
# # 03. Intent Discovery & Topic Clustering
# Empirical clustering on customer messages to discover operational intents.

# %%
import json
import yaml

with open('../results/intent_clusters.json', 'r') as f:
    clusters = json.load(f)

with open('../configs/intents.yaml', 'r') as f:
    intents = yaml.safe_load(f)

print(f"Discovered {len(intents['intents'])} Operational Intents:")
for item in intents['intents']:
    print(f"- {item['id']}: {item['name']}")
