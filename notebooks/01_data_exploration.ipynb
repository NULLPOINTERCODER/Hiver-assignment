# %% [markdown]
# # 01. Data Exploration — Twitter Customer Support Dataset
# Explores conversation threads, schema detection, and multi-turn relationships.

# %%
import pandas as pd
import sys
from pathlib import Path

# Load sample conversations
df = pd.read_parquet('../data/sample/conversations_sample.parquet')
print('Sample shape:', df.shape)
df.head(3)

# %%
# Distribution of message lengths
df['cust_len'] = df['clean_customer_message'].str.len()
df['resp_len'] = df['clean_brand_response'].str.len()
print('Average customer message length:', df['cust_len'].mean())
print('Average brand response length:', df['resp_len'].mean())
