# %% [markdown]
# # 02. Brand Selection Analysis
# Analyzes conversation volume, thread completeness, and domain specificity to select AppleSupport.

# %%
import json
import pandas as pd

with open('../results/brand_selection.json', 'r') as f:
    brands = json.load(f)

brand_df = pd.DataFrame(brands)
print('Top 10 Brands by Conversation Volume & Viability Score:')
brand_df.head(10)

# %%
# Why AppleSupport was selected:
print("Selected brand: AppleSupport")
print("Key criteria: High resolution specificity, clear hardware/software domains, and concise authoritative resolutions.")
